# %%
from sportsreference.nba.roster import Player
from sportsreference.nba.roster import Roster
from sportsreference.nba.teams import Teams
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd

# %% [markdown]
# ### Create Functions for Extracting Player Info

# %%
sc = Player('curryst01')

# %%
# Function to get player info from Player object

def get_player_df(player):
    
    # helper function to get player age during each season
    def get_age(year, bd):
        if year[0] == "Career":
            return None
        else:
            year_dt = datetime(int(year[0][0:4]) + 1, 1, 1)
            age_years = relativedelta(year_dt, bd).years + relativedelta(year_dt, bd).months/12
            return age_years
        
    # helper function to get year for each row and denote rows that contain career totals
    def get_year(ix):
        if ix[0] == "Career":
            return "Career"
        elif ix[0] == "1999-00":
            return "2000"
        else:
            return ix[0][0:2] + ix[0][-2:]
    
    # get player df and add some extra info
    player_df = player.dataframe
    player_df['birth_date'] = player.birth_date
    player_df['player_id'] = player.player_id
    player_df['name'] = player.name
    player_df['year'] = [get_year(ix) for ix in player_df.index]
    player_df['id'] = [player_id + ' ' + year for player_id, year in zip(player_df['player_id'], player_df['year'])]
    player_df['age'] = [get_age(year, bd) for year, bd in zip(player_df.index, player_df['birth_date'])]
    player_df.set_index('id', drop = True, inplace = True)
    
    return player_df

# %%
scdf = get_player_df(sc)

# %%
scdf.columns
# Out:
# Index(['and_ones', 'assist_percentage', 'assists', 'block_percentage',
#        'blocking_fouls', 'blocks', 'box_plus_minus', 'center_percentage',
#        'defensive_box_plus_minus', 'defensive_rebound_percentage',
#        'defensive_rebounds', 'defensive_win_shares', 'dunks',
#        'effective_field_goal_percentage', 'field_goal_attempts',
#        'field_goal_perc_sixteen_foot_plus_two_pointers',
#        'field_goal_perc_ten_to_sixteen_feet',
#        'field_goal_perc_three_to_ten_feet',
#        'field_goal_perc_zero_to_three_feet', 'field_goal_percentage',
#        'field_goals', 'free_throw_attempt_rate', 'free_throw_attempts',
#        'free_throw_percentage', 'free_throws', 'games_played', 'games_started',
#        'half_court_heaves', 'half_court_heaves_made', 'height',
#        'lost_ball_turnovers', 'minutes_played', 'nationality',
#        'net_plus_minus', 'offensive_box_plus_minus', 'offensive_fouls',
#        'offensive_rebound_percentage', 'offensive_rebounds',
#        'offensive_win_shares', 'on_court_plus_minus', 'other_turnovers',
#        'passing_turnovers', 'percentage_field_goals_as_dunks',
#        'percentage_of_three_pointers_from_corner',
#        'percentage_shots_three_pointers', 'percentage_shots_two_pointers',
#        'percentage_sixteen_foot_plus_two_pointers',
#        'percentage_ten_to_sixteen_footers', 'percentage_three_to_ten_footers',
#        'percentage_zero_to_three_footers', 'personal_fouls',
#        'player_efficiency_rating', 'player_id', 'point_guard_percentage',
#        'points', 'points_generated_by_assists', 'position',
#        'power_forward_percentage', 'salary', 'shooting_distance',
#        'shooting_fouls', 'shooting_fouls_drawn', 'shooting_guard_percentage',
#        'shots_blocked', 'small_forward_percentage', 'steal_percentage',
#        'steals', 'take_fouls', 'team_abbreviation', 'three_point_attempt_rate',
#        'three_point_attempts', 'three_point_percentage',
#        'three_point_shot_percentage_from_corner', 'three_pointers',
#        'three_pointers_assisted_percentage', 'total_rebound_percentage',
#        'total_rebounds', 'true_shooting_percentage', 'turnover_percentage',
#        'turnovers', 'two_point_attempts', 'two_point_percentage',
#        'two_pointers', 'two_pointers_assisted_percentage', 'usage_percentage',
#        'value_over_replacement_player', 'weight', 'win_shares',
#        'win_shares_per_48_minutes', 'birth_date', 'name', 'year', 'age'],
#       dtype='object')

# %% [markdown]
# ### Get Data for All Players
# Include everyone who played in the NBA the last 20 years

# %%
# initialize a list of players that we have pulled data for
players_collected = []
season_df_init = 0
career_df_init = 0
season_df = 0
career_df = 0

# iterate through years
for year in range(2020, 1999, -1):
    print('\n' + str(year))
        
    # iterate through all teams in that year
    for team in Teams(year = str(year)).dataframes.index:
        print('\n' + team + '\n')
        
        # iterate through every player on a team roster
        for player_id in Roster(team, year = year, slim = True).players.keys():
            
            # only pull player info if that player hasn't been pulled already
            if player_id not in players_collected:
                
                player = Player(player_id)
                player_info = get_player_df(player)
                player_seasons = player_info[player_info['year'] != "Career"]
                player_career = player_info[player_info['year'] == "Career"]
                
                # create season_df if not initialized
                if not season_df_init:
                    season_df = player_seasons
                    season_df_init = 1
                
                # else concatenate to season_df
                else:
                    season_df = pd.concat([season_df, player_seasons], axis = 0)
                    
                if not career_df_init:
                    career_df = player_career
                    career_df_init = 1
                
                # else concatenate to career_df
                else:
                    career_df = pd.concat([career_df, player_career], axis = 0)
                
                # add player to players_collected
                players_collected.append(player_id)
                print(player.name)
# Out:
# 2020
#
# DAL
#
# Maxi Kleber
# Delon Wright
# Dorian Finney-Smith
# Tim Hardaway Jr.
# Seth Curry
# Justin Jackson
# Jalen Brunson
# Luka Dončić
# Kristaps Porziņģis
# Dwight Powell
# Boban Marjanović
# J.J. Barea
# Courtney Lee
# Willie Cauley-Stein
# Michael Kidd-Gilchrist
# Antonius Cleveland
# Josh Reaves
#
# MIL
#
# Wesley Matthews
# Brook Lopez
# Pat Connaughton
# Robin Lopez
# Donte DiVincenzo
# Giannis Antetokounmpo
# Eric Bledsoe
# Ersan İlyasova
# Khris Middleton
# George Hill
# Kyle Korver
# Sterling Brown
# D.J. Wilson
# Thanasis Antetokounmpo
# Marvin Williams
# Frank Mason III
# Cameron Reynolds
#
# HOU
#
# P.J. Tucker
# Ben McLemore
# James Harden
# Austin Rivers
# Danuel House
# Russell Westbrook
# Thabo Sefolosha
# Eric Gordon
# Chris Clemons
# Tyson Chandler
# Isaiah Hartenstein
# Robert Covington
# Jeff Green
# Michael Frazier
# DeMarre Carroll
# Bruno Caboclo
# William Howard
#
# POR
#
# Anfernee Simons
# CJ McCollum
# Hassan Whiteside
# Damian Lillard
# Gary Trent Jr.
# Carmelo Anthony
# Nassir Little
# Mario Hezonja
# Trevor Ariza
# Rodney Hood
# Caleb Swanigan
# Wenyen Gabriel
# Jaylen Hoard
# Moses Brown
# Zach Collins
# Jusuf Nurkić
#
# ATL
#
# De'Andre Hunter
# Trae Young
# Vince Carter
# TOR
#
# Solomon Alabi
# Anthony Carter
# Gary Forbes
# Jamaal Magloire
#
# NOH
#
# Jerome Dyson
# Jeff Foote
# Carldell Johnson
# Trey Johnson
# Darryl Watkins
#
# CHA
#
# Derrick Brown
# Jamario Moon
# Eduardo Nájera
#
# 2011
#
# DEN
#
#
# NYK
#
# Andy Rautins
#
# HOU
#
# Yao Ming
# Jermaine Taylor
#
# PHO
#
# Zabian Dowdell
# Gani Lawal
# Garret Siler
#
# OKC
#
# Nenad Krstić
# Morris Peterson
#
# SAS
#
# Antonio McDyess
# Ime Udoka
#
# GSW
#
# Charlie Bell
# Rodney Carney
# Acie Law
# Al Thornton
#
# MIA
#
# Carlos Arroyo
# Eddie House
# Zydrunas Ilgauskas
#
# LAL
#
# Derrick Caracter
# Theo Ratliff
# Joe Smith
#
# MIN
#
# Maurice Ager
#
# DAL
#
# Peja Stojaković
#
# MEM
#
# Leon Powe
# Jason Williams
#
# IND
#
# James Posey
#
# UTA
#
# Marcus Cousin
# Kyle Weaver
#
# SAC
#
# Luther Head
# Darnell Jackson
# Eugene Jeter
# Antoine Wright
#
# ORL
#
# Malik Allen
#
# TOR
#
# David Andersen
# Marcus Banks
# Ronald Dupree
# Julian Wright
#
# PHI
#
# Antonio Daniels
# Darius Songaila
#
# LAC
#
# Jarron Collins
# Willie Warren
#
# CHI
#
#
# WAS
#
#
# DET
#
#
# BOS
#
# Shaquille O'Neal
#
# POR
#
# Sean Marks
# Fabricio Oberto
#
# CLE
#
# Joey Graham
# Jawad Williams
#
# ATL
#
# Pape Sy
# Etan Thomas
#
# NOH
#
# Patrick Ewing
# D.J. Mbenga
# Pops Mensah-Bonsu
#
# NJN
#
# Stephen Graham
# Orien Greene
# Quinton Ross
# Mario West
#
# CHA
#
# Sherron Collins
#
# MIL
#
#
# 2010
#
# PHO
#
# Taylor Griffin
# Alando Tucker
#
# GSW
#
# Devean George
# Chris Hunter
# Coby Karl
#
# DEN
#
#
# UTA
#
#
# TOR
#
# Rasho Nesterović
# Patrick O'Bryant
#
# ORL
#
# Anthony Johnson
#
# MEM
#
# Trey Gilder
# Steven Hunter
# Allen Iverson
# Marcus Williams
#
# HOU
#
#
# NYK
#
# Jonathan Bender
# J.R. Giddens
# Marcus Landry
#
# CLE
#
# Cedric Jackson
#
# DAL
#
# Tim Thomas
#
# LAL
#
# Adam Morrison
#
# ATL
#
# Othello Hunter
# Randolph Morris
#
# OKC
#
# Antonio Anderson
# Ryan Bowen
# Kevin Ollie
# Mike Wilks
#
# SAS
#
# Michael Finley
# Malik Hairston
# Marcus Haislip
#
# IND
#
# Travis Diener
#
# NOH
#
# Devin Brown
# Jason Hart
#
# SAC
#
# Desmond Mason
# Sean May
# Kenny Thomas
#
# BOS
#
# Oliver Lafayette
#
# MIN
#
# Nathan Jawai
# Oleksiy Pecherov
#
# POR
#
#
# PHI
#
# Primož Brezec
#
# MIL
#
# Roko Ukić
#
# CHI
#
# Joe Alexander
# Lindsey Hunter
# Brandin Knight
# Rod Strickland
# Bob Sura
# Charlie Ward
# Clarence Weatherspoon
#
# CHI
#
# Lawrence Funderburke
# Frank Williams
#
# CHA
#
# Cory Alexander
# Tamar Slay
# Theron Smith
# Jahidi White
#
# MEM
#
# Ryan Humphrey
#
# DET
#
# Elden Campbell
# Derrick Coleman
# Darvin Ham
# Horace Jenkins
#
# IND
#
# Michael Curry
# Tremaine Fowlkes
# Britton Johnsen
# Reggie Miller
#
# UTA
#
# Curtis Borchardt
# Ben Handlogten
# Raül López
# Aleksandar Radojević
#
# POR
#
# Geno Carlisle
#
# ATL
#
# Jason Collier
# Predrag Drobnjak
# Obinna Ekezie
# Anthony Miller
# Michael Stewart
#
# NJN
#
# Travis Best
# Rodney Buford
# Donnell Harvey
# Ron Mercer
# Jabari Smith
#
# NOH
#
# Corsley Edwards
# Alex Garcia
# George Lynch
#
# 2004
#
# DAL
#
#
# SAC
#
#
# LAL
#
# Maurice Carter
# Rick Fox
# Horace Grant
# Karl Malone
#
# MIL
#
# Dan Langhi
#
# DEN
#
# Jeff Trepagnier
#
# SEA
#
# Leon Smith
#
# MEM
#
# Troy Bell
#
# BOS
#
# Dana Barros
#
# LAC
#
# Doug Overton
# Olden Polynice
# Glen Rice
#
# MIN
#
# Quincy Lewis
# Oliver Miller
# Gary Trent
#
# PHO
#
# Robert Archibald
# Cezary Trybański
#
# ORL
#
# Derrick Dial
# Desmond Penigar
# Sean Rooks
#
# GSW
#
# J.R. Bremer
# Avery Johnson
# Popeye Jones
# Sean Lampley
# Rusty LaRue
# Cherokee Parks
#
# CLE
#
#
# ATL
#
# Chris Crawford
# Hiram Fuller
# Travis Hansen
#
# NYK
#
#
# NOH
#
# Bryce Drew
# Jamal Mashburn
#
# WAS
#
# Mitchell Butler
# Chris Whitney
#
# SAS
#
# Shane Heal
#
# IND
#
#
# POR
#
# Ruben Boumtje-Boumtje
# Desmond Ferguson
# Tracy Murray
# Vladimir Stepania
# Slavko Vraneš
#
# MIA
#
# Jerome Beasley
# Bimbo Coles
# Tyrone Hill
# John Wallace
#
# NJN
#
# Brandon Armstrong
# Hubert Davis
# Robert Pack
#
# DET
#
#
# HOU
#
# Alton Ford
# Mark Jackson
# Charles Oakley
#
# CHI
#
# Corie Blount
# Chris Jefferies
# Scottie Pippen
# Eddie Robinson
#
# UTA
#
# Keon Clark
# Paul Grant
#
# PHI
#
# Amal McCaskill
#
# TOR
#
# Mengke Bateer
#
# 2003
#
# DAL
#
# Tariq Abdul-Wahad
# Evan Eschmeyer
# Adam Harrington
# Antoine Rigaudeau
# Mark Strickland
# Walt Williams
#
# GSW
#
# A.J. Guyton
# Chris Mills
# Dean Oliver
# Guy Rucker
# Óscar Torres
#
# SAC
#
#
# LAL
#
# Soumaila Samake
# Brian Shaw
#
# MIL
#
# Jason Caffey
# Anthony Mason
#
# ORL
#
# Shawn Kemp
# Olumide Oyedeji
# Jeryl Sasser
#
# MIN
#
# Igor Rakočević
# Reggie Slater
# Drew Barry
# Terry Cummings
# Mark Davis
# Tony Farmer
# Tim Legler
# Tim Young
#
# PHI
#
# Stanley Roberts
#
# MIA
#
# Rex Walters
#
# ATL
#
#
# VAN
#
# Antoine Carr
# Dennis Scott
# Joe Stephens
#
# NYK
#
# DeMarco Johnson
# Andrew Lang
#
# LAC
#
# Anthony Avent
# Mario Bennett
# Keith Closs
# Marty Conlon
# Charles Jones
# Eric Murdock
#
# CHI
#
# Chris Anstey
# B.J. Armstrong
# Khalid Reeves
# Dedric Willoughby

# %%
season_df.to_csv('Data/nba_player_stats_by_season.csv')
career_df.to_csv('Data/nba_player_stats_by_career.csv')

# %%
season_df
# Out:
#                and_ones assist_percentage  assists block_percentage  \
# id
# klebima01 2018     None               6.4     51.0              3.5
# klebima01 2019     None               6.8     70.0              4.4
# klebima01 2020     None               6.2     77.0              3.9
# wrighde01 2016     None              22.5     31.0              1.1
# wrighde01 2017     None              18.2     57.0              2.1
# ...                 ...               ...      ...              ...
# reevekh01 1997     None              25.6    226.0              0.5
# reevekh01 1998     None              19.8    230.0              0.4
# reevekh01 1999     None              15.9     11.0                0
# reevekh01 2000     None              46.3     13.0                0
# willode01 2000     None              24.6     66.0              0.3
#
#                blocking_fouls  blocks  box_plus_minus  center_percentage  \
# id
# klebima01 2018           None    47.0            -0.5                0.0
# klebima01 2019           None    78.0             0.4                0.0
# klebima01 2020           None    78.0             0.6                0.0
# wrighde01 2016           None     3.0             0.9                0.0
# wrighde01 2017           None    11.0             2.0                0.0
# ...                       ...     ...             ...                ...
# reevekh01 1997           None     9.0            -2.4                0.0
# reevekh01 1998           None    10.0            -1.9                0.0
# reevekh01 1999           None     0.0            -5.8                0.0
# reevekh01 2000           None     0.0            -5.2                0.0
# willode01 2000           None     2.0            -1.0                0.0
#
#                 defensive_box_plus_minus defensive_rebound_percentage  ...  \
# id                                                                     ...
# klebima01 2018                       0.5                         15.6  ...
# klebima01 2019                       1.2                         16.9  ...
# klebima01 2020                       0.2                         15.5  ...
# wrighde01 2016                      -0.3                         14.3  ...
# wrighde01 2017                       2.1                          8.1  ...
# ...                                  ...                          ...  ...
# reevekh01 1997                      -1.4                          6.9  ...
# reevekh01 1998                      -0.4                          7.6  ...
# reevekh01 1999                      -1.0                          4.4  ...
# reevekh01 2000                      -0.5                            5  ...
# willode01 2000                      -0.4                          9.4  ...
#
#                 two_pointers_assisted_percentage  usage_percentage  \
# id
# klebima01 2018                             0.793              13.7
# klebima01 2019                             0.724              13.5
# klebima01 2020                             0.822              13.9
# wrighde01 2016                             0.161              22.1
# wrighde01 2017                             0.128              16.6
# ...                                          ...               ...
# reevekh01 1997                             0.277              18.7
# reevekh01 1998                             0.292              19.2
# reevekh01 1999                             0.571              14.5
# reevekh01 2000                             0.333              19.3
# willode01 2000                             0.688              21.5
#
#                 value_over_replacement_player weight  win_shares  \
# id
# klebima01 2018                            0.5  240.0         2.8
# klebima01 2019                            0.9  240.0         3.5
# klebima01 2020                            1.1  240.0         4.6
# wrighde01 2016                            0.2  183.0         0.6
# wrighde01 2017                            0.5  183.0         1.1
# ...                                       ...    ...         ...
# reevekh01 1997                           -0.1  199.0         1.2
# reevekh01 1998                            0.0  199.0         2.5
# reevekh01 1999                           -0.1  199.0         0.1
# reevekh01 2000                            0.0  199.0         0.0
# willode01 2000                            0.1  180.0         0.4
#
#                win_shares_per_48_minutes birth_date               name  year  \
# id
# klebima01 2018                     0.113 1992-01-29        Maxi Kleber  2018
# klebima01 2019                     0.111 1992-01-29        Maxi Kleber  2019
# klebima01 2020                     0.131 1992-01-29        Maxi Kleber  2020
# wrighde01 2016                     0.124 1992-04-26       Delon Wright  2016
# wrighde01 2017                     0.117 1992-04-26       Delon Wright  2017
# ...                                  ...        ...                ...   ...
# reevekh01 1997                     0.041 1972-07-15      Khalid Reeves  1997
# reevekh01 1998                     0.062 1972-07-15      Khalid Reeves  1998
# reevekh01 1999                     0.025 1972-07-15      Khalid Reeves  1999
# reevekh01 2000                    -0.046 1972-07-15      Khalid Reeves  2000
# willode01 2000                      0.04 1974-05-27  Dedric Willoughby  2000
#
#                       age
# id
# klebima01 2018  25.916667
# klebima01 2019  26.916667
# klebima01 2020  27.916667
# wrighde01 2016  23.666667
# wrighde01 2017  24.666667
# ...                   ...
# reevekh01 1997  24.416667
# reevekh01 1998  25.416667
# reevekh01 1999  26.416667
# reevekh01 2000  27.416667
# willode01 2000  25.583333
#
# [12736 rows x 93 columns]

# %%
#### Mini Test ####

# initialize a list of players that we have pulled data for
players_collected = []
season_df_init = 0
career_df_init = 0
season_df = 0
career_df = 0


# iterate through every player on a team roster
for player in Roster('GSW', year = 2020).players:

    # only pull player info if that player hasn't been pulled already
    if player.player_id not in players_collected:

        player_info = get_player_df(player)
        player_seasons = player_info[player_info['year'] != "Career"]
        player_career = player_info[player_info['year'] == "Career"]

        # create season_df if not initialized
        if not season_df_init:
            season_df = player_seasons
            season_df_init = 1

        # else concatenate to season_df
        else:
            season_df = pd.concat([season_df, player_seasons], axis = 0)

        if not career_df_init:
            career_df = player_career
            career_df_init = 1

        # else concatenate to career_df
        else:
            career_df = pd.concat([career_df, player_career], axis = 0)

        # add player to players_collected
        players_collected.append(player.player_id)
        
        print(player.name)
# Out:
# Eric Paschall
# Marquese Chriss
# Jordan Poole
# Damion Lee
# Ky Bowman
# Draymond Green
# Kevon Looney
# Alen Smailagić
# Juan Toscano-Anderson
# Andrew Wiggins
# Dragan Bender
# Mychal Mulder
# Stephen Curry
# Chasson Randle
# Klay Thompson

# %%
Teams(year = '2020').dataframes.index
# Out:
# Index(['DAL', 'MIL', 'HOU', 'POR', 'ATL', 'NOP', 'LAC', 'WAS', 'MEM', 'PHO',
#        'MIA', 'MIN', 'BOS', 'TOR', 'LAL', 'DEN', 'SAS', 'PHI', 'IND', 'UTA',
#        'OKC', 'BRK', 'DET', 'NYK', 'SAC', 'CLE', 'CHI', 'ORL', 'GSW', 'CHO'],
#       dtype='object')
